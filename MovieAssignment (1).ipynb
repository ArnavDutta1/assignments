# %%
# Filtering out the warnings so that it does not show any error message on other python versions.

import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the .csv file using "read_csv". Remove content from copied path.
movies=pd.read_csv("drive/MyDrive/Movie+Assignment+Data.csv")
movies.head()
# Out:
#                    Title  title_year  ...  content_rating    Country
# 0             La La Land        2016  ...           PG-13        USA
# 1               Zootopia        2016  ...              PG        USA
# 2                   Lion        2016  ...           PG-13  Australia
# 3                Arrival        2016  ...           PG-13        USA
# 4  Manchester by the Sea        2016  ...               R        USA
#
# [5 rows x 62 columns]

# %% [markdown]
# ***Inspect the dataset.***

# %%
movies.shape   #Check the nos. of rows and columns in the dataframe.
# Out:
# (100, 62)

# %%
movies.info() #to check the columnwise info.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
#  14  MetaCritic              95 non-null     float64
#  15  Runtime                 100 non-null    int64
#  16  CVotes10                100 non-null    int64
#  17  CVotes09                100 non-null    int64
#  18  CVotes08                100 non-null    int64
#  19  CVotes07                100 non-null    int64
#  20  CVotes06                100 non-null    int64
#  21  CVotes05                100 non-null    int64
#  22  CVotes04                100 non-null    int64
#  23  CVotes03                100 non-null    int64
#  24  CVotes02                100 non-null    int64
#  25  CVotes01                100 non-null    int64
#  26  CVotesMale              100 non-null    int64
#  27  CVotesFemale            100 non-null    int64
#  28  CVotesU18               100 non-null    int64
#  29  CVotesU18M              100 non-null    int64
#  30  CVotesU18F              100 non-null    int64
#  31  CVotes1829              100 non-null    int64
#  32  CVotes1829M             100 non-null    int64
#  33  CVotes1829F             100 non-null    int64
#  34  CVotes3044              100 non-null    int64
#  35  CVotes3044M             100 non-null    int64
#  36  CVotes3044F             100 non-null    int64
#  37  CVotes45A               100 non-null    int64
#  38  CVotes45AM              100 non-null    int64
#  39  CVotes45AF              100 non-null    int64
#  40  CVotes1000              100 non-null    int64
#  41  CVotesUS                100 non-null    int64
#  42  CVotesnUS               100 non-null    int64
#  43  VotesM                  100 non-null    float64
#  44  VotesF                  100 non-null    float64
#  45  VotesU18                100 non-null    float64
#  46  VotesU18M               100 non-null    float64
#  47  VotesU18F               100 non-null    float64
#  48  Votes1829               100 non-null    float64
#  49  Votes1829M              100 non-null    float64
#  50  Votes1829F              100 non-null    float64
#  51  Votes3044               100 non-null    float64
#  52  Votes3044M              100 non-null    float64
#  53  Votes3044F              100 non-null    float64
#  54  Votes45A                100 non-null    float64
#  55  Votes45AM               100 non-null    float64
#  56  Votes45AF               100 non-null    float64
#  57  Votes1000               100 non-null    float64
#  58  VotesUS                 100 non-null    float64
#  59  VotesnUS                100 non-null    float64
#  60  content_rating          100 non-null    object
#  61  Country                 100 non-null    object
# dtypes: float64(21), int64(32), object(9)
# memory usage: 48.6+ KB

# %%
movies.describe() #to check the summary for the numeric columns
# Out:
#         title_year      budget       Gross  ...    VotesnUS      profit  Avg_rating
# count   100.000000  100.000000  100.000000  ...  100.000000  100.000000   95.000000
# mean   2012.820000   78.384000  146.867867  ...    7.793000   68.483867    7.858947
# std       1.919491   74.452947  145.400370  ...    0.264099  101.130141    0.488374
# min    2010.000000    3.000000    0.223838  ...    7.300000  -96.179906    6.950000
# 25%    2011.000000   15.750000   41.997524  ...    7.600000   16.873283    7.475000
# 50%    2013.000000   42.250000  107.026591  ...    7.750000   38.619583    7.850000
# 75%    2014.000000  150.000000  210.754845  ...    7.925000  104.954057    8.125000
# max    2016.000000  260.000000  936.662225  ...    8.800000  691.662225    8.950000
#
# [8 rows x 55 columns]

# %%
movies["Gross"]=movies["Gross"]/1000000
movies["budget"]=movies["budget"]/1000000 #reducing the numbers so that it's readable by  dividing it by 1000000
movies
# Out:
#                                            Title  ...    Country
# 0                                     La La Land  ...        USA
# 1                                       Zootopia  ...        USA
# 2                                           Lion  ...  Australia
# 3                                        Arrival  ...        USA
# 4                          Manchester by the Sea  ...        USA
# ..                                           ...  ...        ...
# 95                                      Whiplash  ...        USA
# 96                               Before Midnight  ...        USA
# 97    Star Wars: Episode VII - The Force Awakens  ...        USA
# 98  Harry Potter and the Deathly Hallows: Part I  ...         UK
# 99                       Tucker and Dale vs Evil  ...     Canada
#
# [100 rows x 62 columns]

# %%
movies["profit"]=movies["Gross"]-movies["budget"] #Creating profit column
movies
# Out:
#                                            Title  ...      profit
# 0                                     La La Land  ...  121.101803
# 1                                       Zootopia  ...  191.268248
# 2                                           Lion  ...   39.738905
# 3                                        Arrival  ...   53.546139
# 4                          Manchester by the Sea  ...   38.695371
# ..                                           ...  ...         ...
# 95                                      Whiplash  ...    9.792000
# 96                               Before Midnight  ...    5.114507
# 97    Star Wars: Episode VII - The Force Awakens  ...  691.662225
# 98  Harry Potter and the Deathly Hallows: Part I  ...  146.347721
# 99                       Tucker and Dale vs Evil  ...   -4.776162
#
# [100 rows x 63 columns]

# %%
movies=movies.sort_values(by="profit",ascending=False)

# %%
movies.iloc[:10,:] #movies sorted in terms of profit
# Out:
#                                          Title  ...      profit
# 97  Star Wars: Episode VII - The Force Awakens  ...  691.662225
# 11                                The Avengers  ...  403.279547
# 47                                    Deadpool  ...  305.024263
# 32             The Hunger Games: Catching Fire  ...  294.645577
# 12                                 Toy Story 3  ...  214.984497
# 8                        The Dark Knight Rises  ...  198.130642
# 45                              The Lego Movie  ...  197.756197
# 1                                     Zootopia  ...  191.268248
# 41                               Despicable Me  ...  182.501645
# 18                                  Inside Out  ...  181.454367
#
# [10 rows x 63 columns]

# %%
sns.jointplot("budget","profit",movies)
plt.show()

# %% [markdown]
# **As there are movies earning negative profit, we will find the movies.**

# %%
movies[movies["profit"]<0]
# Out:
#                           Title  title_year  ...  Country     profit
# 99      Tucker and Dale vs Evil        2010  ...   Canada  -4.776162
# 89                        Amour        2012  ...   France  -8.674623
# 56                         Rush        2013  ...       UK -11.096291
# 66                      Warrior        2011  ...      USA -11.348338
# 82                      Flipped        2010  ...      USA -12.247786
# 28           X-Men: First Class        2011  ...      USA -13.594629
# 46  Scott Pilgrim vs. the World        2010  ...      USA -28.505730
# 7                       Tangled        2010  ...      USA -59.192738
# 17             Edge of Tomorrow        2014  ...      USA -77.810499
# 39            The Little Prince        2015  ...   France -79.860848
# 22                         Hugo        2011  ...      USA -96.179906
#
# [11 rows x 63 columns]

# %% [markdown]
# **Find the movie Tangled.**

# %%
movies["MetaCritic"]=movies["MetaCritic"]/10

# %%
movies["Avg_rating"]=(movies["IMDb_rating"]+movies["MetaCritic"])/2

# %%
df=movies[["Title","IMDb_rating","MetaCritic","Avg_rating"]]
df=df.loc[abs(df["IMDb_rating"]-df["MetaCritic"]<0.5)]

# %%
df=df.sort_values(by="Avg_rating",ascending=False)
world_wide_loved_movies=df.loc[df["Avg_rating"]>=8]
world_wide_loved_movies
# Out:
#                                               Title  ...  Avg_rating
# 94                                          Boyhood  ...        8.95
# 69                                 12 Years a Slave  ...        8.85
# 18                                       Inside Out  ...        8.80
# 12                                      Toy Story 3  ...        8.75
# 0                                        La La Land  ...        8.75
# 4                             Manchester by the Sea  ...        8.75
# 70                                        Spotlight  ...        8.70
# 34                                          Gravity  ...        8.70
# 96                                  Before Midnight  ...        8.65
# 89                                            Amour  ...        8.65
# 95                                         Whiplash  ...        8.65
# 53                               The Social Network  ...        8.60
# 29                               Mad Max: Fury Road  ...        8.55
# 67                                              Her  ...        8.50
# 65                         The Grand Budapest Hotel  ...        8.45
# 77                                       The Artist  ...        8.40
# 76                                The King's Speech  ...        8.40
# 72  Birdman or (The Unexpected Virtue of Ignorance)  ...        8.30
# 35                                 Django Unchained  ...        8.25
# 5                                Hell or High Water  ...        8.25
# 93                               Dallas Buyers Club  ...        8.20
# 51                                             Argo  ...        8.15
# 87                                         Nebraska  ...        8.15
# 49                                        Moneyball  ...        8.15
# 97       Star Wars: Episode VII - The Force Awakens  ...        8.10
# 75                                 Moonrise Kingdom  ...        8.10
# 48                                 Captain Phillips  ...        8.05
# 3                                           Arrival  ...        8.05
# 45                                   The Lego Movie  ...        8.05
# 33                                      The Martian  ...        8.00
# 43                                        Gone Girl  ...        8.00
#
# [31 rows x 4 columns]

# %%
movies.pivot_table(values=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],
                   aggfunc="sum",index=["actor_1_name","actor_2_name","actor_3_name"])
# Out:
#                                                     actor_1_facebook_likes  ...  actor_3_facebook_likes
# actor_1_name  actor_2_name    actor_3_name                                  ...
# Aidan Turner  Adam Brown      James Nesbitt                          10000  ...                  1546.0
# Albert Finney Helen McCrory   Rory Kinnear                             883  ...                   393.0
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559  ...                   303.0
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000  ...                     0.0
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000  ...                   384.0
# ...                                                                    ...  ...                     ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000  ...                   423.0
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000  ...                   943.0
#               Christian Bale  Joseph Gordon-Levitt                   27000  ...                 23000.0
#               Frank Grillo    Kevin Dunn                             27000  ...                   581.0
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565  ...                   171.0
#
# [99 rows x 3 columns]

# %%
group=movies.pivot_table(values=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],
                   aggfunc="sum",index=["actor_1_name","actor_2_name","actor_3_name"])
group
# Out:
#                                                     actor_1_facebook_likes  ...  actor_3_facebook_likes
# actor_1_name  actor_2_name    actor_3_name                                  ...
# Aidan Turner  Adam Brown      James Nesbitt                          10000  ...                  1546.0
# Albert Finney Helen McCrory   Rory Kinnear                             883  ...                   393.0
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559  ...                   303.0
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000  ...                     0.0
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000  ...                   384.0
# ...                                                                    ...  ...                     ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000  ...                   423.0
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000  ...                   943.0
#               Christian Bale  Joseph Gordon-Levitt                   27000  ...                 23000.0
#               Frank Grillo    Kevin Dunn                             27000  ...                   581.0
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565  ...                   171.0
#
# [99 rows x 3 columns]

# %%
group["Total likes"]=group["actor_1_facebook_likes"]+group["actor_2_facebook_likes"]+group["actor_3_facebook_likes"]
group
# Out:
#                                                     actor_1_facebook_likes  ...  Total likes
# actor_1_name  actor_2_name    actor_3_name                                  ...
# Aidan Turner  Adam Brown      James Nesbitt                          10000  ...      13490.0
# Albert Finney Helen McCrory   Rory Kinnear                             883  ...       1839.0
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559  ...       1289.0
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000  ...      40300.0
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000  ...       2151.0
# ...                                                                    ...  ...          ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000  ...      15958.0
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000  ...      36943.0
#               Christian Bale  Joseph Gordon-Levitt                   27000  ...      73000.0
#               Frank Grillo    Kevin Dunn                             27000  ...      28379.0
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565  ...       1291.0
#
# [99 rows x 4 columns]

# %%
group.sort_values(by="Total likes",ascending=False,inplace=True)

# %%
group
# Out:
#                                                                     actor_1_facebook_likes  ...  Total likes
# actor_1_name             actor_2_name       actor_3_name                                    ...
# Dev Patel                Nicole Kidman      Rooney Mara                              33000  ...     138800.0
# Leonardo DiCaprio        Tom Hardy          Joseph Gordon-Levitt                     29000  ...      79000.0
# Jennifer Lawrence        Peter Dinklage     Hugh Jackman                             34000  ...      76000.0
# Casey Affleck            Michelle Williams  Kyle Chandler                              518  ...      74818.0
# Tom Hardy                Christian Bale     Joseph Gordon-Levitt                     27000  ...      73000.0
# ...                                                                                    ...  ...          ...
# Ellar Coltrane           Lorelei Linklater  Libby Villari                              230  ...        550.0
# Elina Alminas            Sonoya Mizuno      Corey Johnson                              149  ...        417.0
# Seamus Davey-Fitzpatrick Ariane Labed       Athina Rachel Tsangari                     140  ...        251.0
# Doug Walker              Rob Walker         0                                          131  ...        143.0
# Phaldut Sharma           Basher Savage      Amy Warren                                  39  ...         75.0
#
# [99 rows x 4 columns]

# %%
group.reset_index(inplace=True)

# %%
group
# Out:
#                 actor_1_name  ... Total likes
# 0                  Dev Patel  ...    138800.0
# 1          Leonardo DiCaprio  ...     79000.0
# 2          Jennifer Lawrence  ...     76000.0
# 3              Casey Affleck  ...     74818.0
# 4                  Tom Hardy  ...     73000.0
# ..                       ...  ...         ...
# 94            Ellar Coltrane  ...       550.0
# 95             Elina Alminas  ...       417.0
# 96  Seamus Davey-Fitzpatrick  ...       251.0
# 97               Doug Walker  ...       143.0
# 98            Phaldut Sharma  ...        75.0
#
# [99 rows x 7 columns]

# %%
group=group.iloc[0:5,:]

# %%
group
# Out:
#         actor_1_name        actor_2_name  ... actor_3_facebook_likes  Total likes
# 0          Dev Patel       Nicole Kidman  ...                 9800.0     138800.0
# 1  Leonardo DiCaprio           Tom Hardy  ...                23000.0      79000.0
# 2  Jennifer Lawrence      Peter Dinklage  ...                20000.0      76000.0
# 3      Casey Affleck  Michelle Williams   ...                 3300.0      74818.0
# 4          Tom Hardy      Christian Bale  ...                23000.0      73000.0
#
# [5 rows x 7 columns]

# %%
j=0
for i in group["Total likes"]:
    temp=sorted([group.loc[j,"actor_1_facebook_likes"],group.loc[j,"actor_2_facebook_likes"],group.loc[j,"actor_3_facebook_likes"]])
    if temp[0]>= temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2:
        print(sorted([group.loc[j,"actor_1_name"],group.loc[j,"actor_2_name"],group.loc[j,"actor_3_name"]]))
    j=j+1
# Out:
# ['Joseph Gordon-Levitt', 'Leonardo DiCaprio', 'Tom Hardy']
# ['Hugh Jackman', 'Jennifer Lawrence', 'Peter Dinklage']
# ['Christian Bale', 'Joseph Gordon-Levitt', 'Tom Hardy']

# %%
plt.hist(movies["Runtime"])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
movies.loc[movies["content_rating"]=="R"].sort_values(by="CVotesU18",ascending=False)[["Title","CVotesU18"]].head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %%
df_by_genre=movies.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=movies[["genre_1","genre_2","genre_3"]]
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  ...    genre_1    genre_2  genre_3
# 97    155391    161810    166378  ...     Action  Adventure  Fantasy
# 11    260257    234203    264290  ...     Action     Sci-Fi      NaN
# 47    147467    147966    170810  ...     Action  Adventure   Comedy
# 32     85219     83874    150153  ...     Action  Adventure  Mystery
# 12    139773    149992    158704  ...  Animation  Adventure   Comedy
# ..       ...       ...       ...  ...        ...        ...      ...
# 46     47292     48976     79198  ...     Action     Comedy  Romance
# 7      56575     54688     97207  ...  Animation  Adventure   Comedy
# 17     60383     99596    175961  ...     Action  Adventure   Sci-Fi
# 39      7565      7321     11668  ...  Animation  Adventure    Drama
# 22     29228     40728     77893  ...  Adventure      Drama   Family
#
# [100 rows x 47 columns]

# %%
df_by_genre["cnt"]=1
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  ...    genre_1    genre_2  genre_3  cnt
# 97    155391    161810    166378     99402  ...     Action  Adventure  Fantasy    1
# 11    260257    234203    264290    162604  ...     Action     Sci-Fi      NaN    1
# 47    147467    147966    170810    105717  ...     Action  Adventure   Comedy    1
# 32     85219     83874    150153    121748  ...     Action  Adventure  Mystery    1
# 12    139773    149992    158704     88289  ...  Animation  Adventure   Comedy    1
# ..       ...       ...       ...       ...  ...        ...        ...      ...  ...
# 46     47292     48976     79198     59689  ...     Action     Comedy  Romance    1
# 7      56575     54688     97207     70947  ...  Animation  Adventure   Comedy    1
# 17     60383     99596    175961    100724  ...     Action  Adventure   Sci-Fi    1
# 39      7565      7321     11668      8558  ...  Animation  Adventure    Drama    1
# 22     29228     40728     77893     62936  ...  Adventure      Drama   Family    1
#
# [100 rows x 48 columns]

# %%
df_by_g1=df_by_genre.groupby("genre_1").aggregate(np.sum)
df_by_g2=df_by_genre.groupby("genre_2").aggregate(np.sum)
df_by_g3=df_by_genre.groupby("genre_3").aggregate(np.sum)

# %%
df_by_g1.add(df_by_g2)
# Out:
#             CVotes10   CVotes09   CVotes08  ...  VotesUS  VotesnUS   cnt
# Action     3166467.0  3547429.0  4677755.0  ...    247.6     240.6  31.0
# Adventure  3356599.0  3728682.0  4832266.0  ...    271.7     265.1  34.0
# Animation        NaN        NaN        NaN  ...      NaN       NaN   NaN
# Biography   852003.0  1401608.0  2231078.0  ...    142.7     139.9  18.0
# Comedy      800212.0  1121625.0  1624557.0  ...    126.4     123.7  16.0
# Crime       402866.0   730468.0  1168828.0  ...     79.7      77.7  10.0
# Drama      3004217.0  4255290.0  5939726.0  ...    421.4     413.7  53.0
# Family           NaN        NaN        NaN  ...      NaN       NaN   NaN
# Fantasy          NaN        NaN        NaN  ...      NaN       NaN   NaN
# History          NaN        NaN        NaN  ...      NaN       NaN   NaN
# Horror           NaN        NaN        NaN  ...      NaN       NaN   NaN
# Music            NaN        NaN        NaN  ...      NaN       NaN   NaN
# Musical          NaN        NaN        NaN  ...      NaN       NaN   NaN
# Mystery     235718.0   383463.0   512318.0  ...     23.7      23.7   3.0
# Romance          NaN        NaN        NaN  ...      NaN       NaN   NaN
# Sci-Fi           NaN        NaN        NaN  ...      NaN       NaN   NaN
# Sport            NaN        NaN        NaN  ...      NaN       NaN   NaN
# Thriller         NaN        NaN        NaN  ...      NaN       NaN   NaN
# War              NaN        NaN        NaN  ...      NaN       NaN   NaN
# Western          NaN        NaN        NaN  ...      NaN       NaN   NaN
#
# [20 rows x 45 columns]

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  ...  VotesUS  VotesnUS  cnt
# genre_1                                  ...
# Action      2928407   3261919   4247693  ...    215.8     209.5   27
# Adventure   1058779   1179818   1560541  ...     95.3      93.5   12
# Animation    681562    798227   1153214  ...     87.6      86.1   11
# Biography    666831   1088430   1654704  ...    103.3     101.5   13
# Comedy       371217    496905    770395  ...     70.9      69.4    9
# Crime        383290    690221   1083469  ...     71.9      70.1    9
# Drama       1080725   1494053   1827363  ...    143.2     141.1   18
# Mystery      150405    230844    278844  ...      7.8       8.1    1
#
# [8 rows x 45 columns]

# %%
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  ...  VotesUS  VotesnUS  cnt
# genre_2                                  ...
# Action       238060    285510    430062  ...     31.8      31.1    4
# Adventure   2297820   2548864   3271725  ...    176.4     171.6   22
# Biography    185172    313178    576374  ...     39.4      38.4    5
# Comedy       428995    624720    854162  ...     55.5      54.3    7
# Crime         19576     40247     85359  ...      7.8       7.6    1
# Drama       1923492   2761237   4112363  ...    278.2     272.6   35
# Family        68937     54947    102488  ...      7.9       7.5    1
# Fantasy      270616    290831    447307  ...     23.4      23.2    3
# History       15757     32840     83322  ...      7.7       7.5    1
# Horror        16572     19818     44460  ...      7.7       7.5    1
# Music        110404    161864    132656  ...      8.6       8.4    1
# Musical       54268     47750     63323  ...      7.6       7.5    1
# Mystery       85313    152619    233474  ...     15.9      15.6    2
# Romance      230425    270702    353326  ...     39.7      39.2    5
# Sci-Fi       350243    361819    433983  ...     16.2      15.7    2
# Sport         21364     28964     58237  ...      7.9       7.5    1
# Thriller     624792    709424    734770  ...     24.2      24.5    3
# War           15911     17607     32570  ...      7.6       7.5    1
# Western      234824    339329    286911  ...      8.4       8.4    1
#
# [19 rows x 45 columns]

# %%
df_add=df_by_g1.add(df_by_g2,fill_value=0)
df_add=df_add.add(df_by_g3,fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08  ...  VotesUS  VotesnUS   cnt
# Action     3166467.0  3547429.0  4677755.0  ...    247.6     240.6  31.0
# Adventure  3594659.0  4014192.0  5262328.0  ...    303.5     296.2  38.0
# Animation   681562.0   798227.0  1153214.0  ...     87.6      86.1  11.0
# Biography   852003.0  1401608.0  2231078.0  ...    142.7     139.9  18.0
# Comedy     1383616.0  1774987.0  2506851.0  ...    182.6     178.9  23.0
# Crime       574526.0   967118.0  1419495.0  ...     87.8      85.8  11.0
# Drama      3404438.0  4935375.0  7107053.0  ...    515.9     506.0  65.0
# Family       98165.0    95675.0   180381.0  ...     15.6      15.0   2.0
# Fantasy     572452.0   602223.0   889767.0  ...     54.9      53.7   7.0
# History     151261.0   260387.0   394531.0  ...     32.2      31.2   4.0
# Horror       16572.0    19818.0    44460.0  ...      7.7       7.5   1.0
# Music       184649.0   233055.0   197296.0  ...     16.9      16.5   2.0
# Musical      54268.0    47750.0    63323.0  ...      7.6       7.5   1.0
# Mystery     510164.0   827124.0  1166485.0  ...     55.6      55.0   7.0
# Romance     549959.0   689492.0  1069280.0  ...    101.8     100.1  13.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  ...    137.5     134.0  17.0
# Sport       117081.0   169246.0   273043.0  ...     23.9      23.1   3.0
# Thriller   1081701.0  1465491.0  1993378.0  ...    103.1     101.5  13.0
# War          52664.0    72310.0   143841.0  ...     15.2      15.0   2.0
# Western     255918.0   380230.0   378736.0  ...     16.3      16.0   2.0
#
# [20 rows x 45 columns]

# %%
genre_top_10=df_add.loc[df_add["cnt"]>10]

# %%
genre_top_10.iloc[:,0:-1] = genre_top_10.iloc[:,0:-1].divide(genre_top_10["cnt"],axis=0)

# %%
genre_top_10
# Out:
#                 CVotes10       CVotes09  ...  VotesnUS   cnt
# Action     102144.096774  114433.193548  ...  7.761290  31.0
# Adventure   94596.289474  105636.631579  ...  7.794737  38.0
# Animation   61960.181818   72566.090909  ...  7.827273  11.0
# Biography   47333.500000   77867.111111  ...  7.772222  18.0
# Comedy      60157.217391   77173.347826  ...  7.778261  23.0
# Crime       52229.636364   87919.818182  ...  7.800000  11.0
# Drama       52375.969231   75928.846154  ...  7.784615  65.0
# Romance     42304.538462   53037.846154  ...  7.700000  13.0
# Sci-Fi     136781.411765  148873.823529  ...  7.882353  17.0
# Thriller    83207.769231  112730.076923  ...  7.807692  13.0
#
# [10 rows x 45 columns]

# %%
genre_top_10.loc[:,"VotesM":"VotesnUS"]=round(genre_top_10.loc[:,"VotesM":"VotesnUS"],2)

# %%
genre_top_10
# Out:
#                 CVotes10       CVotes09       CVotes08  ...  VotesUS  VotesnUS   cnt
# Action     102144.096774  114433.193548  150895.322581  ...     7.99      7.76  31.0
# Adventure   94596.289474  105636.631579  138482.315789  ...     7.99      7.79  38.0
# Animation   61960.181818   72566.090909  104837.636364  ...     7.96      7.83  11.0
# Biography   47333.500000   77867.111111  123948.777778  ...     7.93      7.77  18.0
# Comedy      60157.217391   77173.347826  108993.521739  ...     7.94      7.78  23.0
# Crime       52229.636364   87919.818182  129045.000000  ...     7.98      7.80  11.0
# Drama       52375.969231   75928.846154  109339.276923  ...     7.94      7.78  65.0
# Romance     42304.538462   53037.846154   82252.307692  ...     7.83      7.70  13.0
# Sci-Fi     136781.411765  148873.823529  176646.705882  ...     8.09      7.88  17.0
# Thriller    83207.769231  112730.076923  153336.769231  ...     7.93      7.81  13.0
#
# [10 rows x 45 columns]

# %%
genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)

# %%
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  ...  VotesUS  VotesnUS   cnt
# Action       102144    114433    150895  ...     7.99      7.76  31.0
# Adventure     94596    105636    138482  ...     7.99      7.79  38.0
# Animation     61960     72566    104837  ...     7.96      7.83  11.0
# Biography     47333     77867    123948  ...     7.93      7.77  18.0
# Comedy        60157     77173    108993  ...     7.94      7.78  23.0
# Crime         52229     87919    129045  ...     7.98      7.80  11.0
# Drama         52375     75928    109339  ...     7.94      7.78  65.0
# Romance       42304     53037     82252  ...     7.83      7.70  13.0
# Sci-Fi       136781    148873    176646  ...     8.09      7.88  17.0
# Thriller      83207    112730    153336  ...     7.93      7.81  13.0
#
# [10 rows x 45 columns]

# %%
sns.barplot(x=genre_top_10["cnt"],y=genre_top_10.index)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.heatmap(genre_top_10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]],annot=True,cmap="coolwarm")
plt.subplot(1,2,2)
sns.heatmap(genre_top_10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]],annot=True,cmap="coolwarm")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **INFERENCE**
# 1.   Inference 1- The romance genere is least liked by any age group of males but no such pattern can be ovserved with females.
# 2.  Inference2- 18-29 is the most active voting group irrespective of gender.
# 3. Inference3- The second most genre liked by male is action and for female is the annimation genre.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.heatmap(genre_top_10[["VotesU18M","Votes1829M","Votes3044M","Votes45AM"]],annot=True,cmap="coolwarm")
plt.subplot(1,2,2)
sns.heatmap(genre_top_10[["VotesU18F","Votes1829F","Votes3044F","Votes45AF"]],annot=True,cmap="coolwarm")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **INFERENCES**
#
# 1.   Inference 1- Ratings among males seems to be decreasing as the age is increasing. The pattern seems to be same with females but with a few exceptions.
# 2.   Inference 2- The crime genre is the most voted genre among U18 M but as for females it is not so.
# 3.   Inference 3- Romance genre has the least voting among all age groups.

# %%
movies["Country"].value_counts()
# Out:
# USA          81
# UK           11
# Australia     3
# France        3
# Canada        1
# Spain         1
# Name: Country, dtype: int64

# %%
movies["IFUS"]=movies["Country"].copy()

# %%
movies.loc[movies["IFUS"]!="USA","IFUS"]="non-USA"

# %%
movies["IFUS"].value_counts()
# Out:
# USA        81
# non-USA    19
# Name: IFUS, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(x="IFUS",y="CVotesUS",data=movies)
plt.subplot(1,2,2)
sns.boxplot(x="IFUS",y="CVotesnUS",data=movies)
plt.show()

# %% [markdown]
# *  Inference 1- US movies has got more votes the non-US movies when medians of box plots are compared.
# *  Inference 2- Non-US movies has a more uniformed voting as compared to non-US movies.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(x="IFUS",y="VotesUS",data=movies)
plt.subplot(1,2,2)
sns.boxplot(x="IFUS",y="VotesnUS",data=movies)
plt.show()

# %% [markdown]
# **INFERENCE**
#
# *   Inference 1- Non-US voters have rated the US and non-US movies lower as compared to the US voters which is clearly visible from the medians.
# *   Inference 2- The people of US has given more ratings then the non-US people for US movies.
# *   Inferemce 3- Some US movies has an expectionally higher ratings from both US and non-US people whereas it is not the same for the non-US movies.

# %%
genre_top_10=genre_top_10.sort_values("CVotes1000",ascending=False)

# %%
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  ...  VotesUS  VotesnUS   cnt
# Sci-Fi       136781    148873    176646  ...     8.09      7.88  17.0
# Action       102144    114433    150895  ...     7.99      7.76  31.0
# Thriller      83207    112730    153336  ...     7.93      7.81  13.0
# Adventure     94596    105636    138482  ...     7.99      7.79  38.0
# Crime         52229     87919    129045  ...     7.98      7.80  11.0
# Comedy        60157     77173    108993  ...     7.94      7.78  23.0
# Biography     47333     77867    123948  ...     7.93      7.77  18.0
# Drama         52375     75928    109339  ...     7.94      7.78  65.0
# Animation     61960     72566    104837  ...     7.96      7.83  11.0
# Romance       42304     53037     82252  ...     7.83      7.70  13.0
#
# [10 rows x 45 columns]

# %%
genre_top_10["CVotes1000"]
# Out:
# Sci-Fi       714
# Action       681
# Thriller     669
# Adventure    662
# Crime        620
# Comedy       605
# Biography    600
# Drama        585
# Animation    578
# Romance      548
# Name: CVotes1000, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.barplot(genre_top_10.index,genre_top_10["CVotes1000"])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ***INFERENCE***
#
# *   Inference1- The voting pattern most resembles in age group vs genre heat maps.
# *   Inference2- Although genre drama has most number of movies produced yet number of votes received is low.
